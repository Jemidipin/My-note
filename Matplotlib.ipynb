# %%
import matplotlib.pyplot as plt
x=[0,1,2,3,4,5]
y=[4,1,8,22,18,8]
plt.plot(x,y)
plt.xlabel("days")
plt.ylabel("counts")
plt.show()

# %%
import numpy as np
x=np.arange(0,400)
y=np.cos(x)
plt.plot(x,y)
plt.ylim(-0.5,0.5)
plt.show()

# %%
import numpy as np
x=np.arange(0,400)
y=np.cos(x)
plt.plot(x,y)
plt.xlim(0,20)
plt.show()

# %% [markdown]
# ### Bar charts

# %%
x=["monday","tuesday","wednesday","thursday","friday"]
y=[0,1,2,3,4]
plt.bar(x,y)
plt.xlabel("days")
plt.ylabel("counts")
plt.show()

# %% [markdown]
# ### Pie chart

# %%
countries=["India","USA","UK","UAE"]
population=[123,23,30,40]
plt.pie(population,labels=countries,autopct="%1.2f%%")#2 digit precision (decimal points)
plt.show()

# %% [markdown]
# ### Histogram

# %%
import pandas as pd 
data=pd.read_csv("D:\\ICT_DataScience\\auto-mpg.csv")
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
plt.hist(data["mpg"],color="r",rwidth=0.8,density=True)
plt.title("histogram of MPG")
plt.xlabel("MPG")
plt.ylabel("density")
plt.xticks([5,10,15,20,25,30,35,40,45,50]) 
plt.yticks()
plt.show()

# %% [markdown]
# ## scatter plot

# %%
plt.figure(figsize=(10,3))
plt.scatter(data["weight"],data["mpg"],c="r",marker="*")
plt.title("MPG vs weight")
plt.xlabel("weight")
plt.ylabel("mpg") 
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,1,1)
plt.scatter(data["weight"],data["mpg"],c="r",marker="*")
plt.xlabel("weight")
plt.ylabel("mpg") 
plt.subplot(2,1,2) 
plt.scatter(data["displacement"],data["mpg"],c="b",marker="*")
plt.xlabel("displacement")
plt.ylabel("mpg") 
plt.show()

# %%
x=np.random.normal(150,10,14500)
plt.hist(x,color="r",bins=100)
# Out:
# (array([  2.,   1.,   2.,   1.,   1.,   3.,   8.,   2.,   8.,   4.,   7.,
#          11.,   7.,  30.,  18.,  22.,  21.,  41.,  32.,  44.,  64.,  62.,
#          75.,  83.,  96.,  85., 108., 151., 154., 180., 206., 192., 237.,
#         234., 252., 292., 305., 326., 317., 356., 369., 390., 422., 425.,
#         414., 398., 432., 421., 428., 409., 420., 385., 425., 356., 385.,
#         417., 324., 342., 307., 274., 277., 268., 243., 198., 212., 207.,
#         181., 148., 129., 100., 102., 105.,  84.,  75.,  65.,  64.,  35.,
#          41.,  28.,  30.,  21.,  16.,  19.,  12.,  14.,   6.,   8.,   5.,
#           8.,   2.,   1.,   6.,   1.,   2.,   0.,   1.,   1.,   1.,   0.,
#           1.]),
#  array([114.20850624, 114.9532499 , 115.69799357, 116.44273724,
#         117.1874809 , 117.93222457, 118.67696824, 119.4217119 ,
#         120.16645557, 120.91119924, 121.6559429 , 122.40068657,
#         123.14543024, 123.8901739 , 124.63491757, 125.37966124,
# ...

# %%
a=np.random.normal(150,10,14500)
b=np.random.normal(170,10,20500)
plt.hist(a,bins=200,color="r")
plt.hist(b,bins=200,color="g",alpha=0.2)
plt.show()

# %%
y=np.random.uniform(0,10,25000)
plt.hist(y,color="r")
# Out:
# (array([2464., 2464., 2585., 2507., 2516., 2389., 2526., 2514., 2442.,
#         2593.]),
#  array([5.04498072e-04, 1.00036746e+00, 2.00023042e+00, 3.00009338e+00,
#         3.99995634e+00, 4.99981930e+00, 5.99968226e+00, 6.99954522e+00,
#         7.99940818e+00, 8.99927114e+00, 9.99913410e+00]),
#  <BarContainer object of 10 artists>)

# %%
data[["mpg"]].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
a=np.random.normal(150,1,2000)
b=np.random.normal(170,5,2000)
plt.scatter(a,b,c="r")

# %%
c=a*-10+b
plt.scatter(a,c,color="r")

# %% [markdown]
# ### heatmaps

# %%
import seaborn as sns
heat_data=np.array([[0,0.4,1],[1,0.4,0]]) 
sns.heatmap(heat_data)
# Out:
# <Axes: >

# %% [markdown]
# ### Box plot

# %%
a=np.random.normal(150,1,2000)#mean,std,
#q1=np.quantile(a, 0.25)
#q3=np.quantile(a, 0.75) is same as np.percentile(a,75)
#iqr=q3-q1
#lower_bound=q1-(1.5*iqr) 
#upper_bound=q3+(1.5*iqr) 
sns.boxplot(a)
# Out:
# <Axes: >

# %% [markdown]
# ### feature extraction and transformation
# #### features and labels
# #### featurization
# * text data
#      - bow

# %%
from scipy import stats
import matplotlib.pyplot as plt 
data=np.random.exponential(scale=1,size=1000) 
transformed_data,lamda_value=stats.boxcox(data) 
plt.figure(figsize=(8,5))
plt.subplot(1,2,1) 
plt.hist(data,bins=30,color="r") 
plt.title("original_data",color="b")
plt.subplot(1,2,2) 
plt.hist(transformed_data,bins=30,color="g") 
plt.title("box-cox transformed_data",color="b")
plt.show()

# %% [markdown]
# ### bow example
